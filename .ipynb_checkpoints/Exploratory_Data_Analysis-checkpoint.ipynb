# %% [markdown]
# ## AI Gen Business Intelligence Analysis Report of Heart Disease Dataset
#
# #### This report presents an analysis of mortality rates for heart disease and stroke. The dataset contains the data of 9 years ranging from 2010 to 2019 from Autuage County, Alabama, and several other counties. The purpose of this report is to explore trends, patterns and outliers in mortality rates across different causes of death, demographic groups, and years. The dataset has different features such as age group, sex, location, state, county, mortality rate, confLow, confHigh, and year. The dataset contains information on mortality rates for different causes of death that may includes:
#
# - **All heart disease**
#
# - **All stroke**
#
# - **Coronary heart disease**
#
# - **Cardiovascular disease**
#
# + **Heart failure**
#
# - **Heart Disease**
#
# **Overall Mortality Rate**
#
#  Mortality rates for all heart disease reduced from 148.8 per 100,000 in 2010 to 80.2 per 100,000 in 2019.
#
#  Significant fluctuations were observed, with notable peaks in 2010 and dips in the following years.
#
#  **Gender Difference**
#
#  Mortality rates for men were consistently higher than those for women.
#
#  Both genders experienced a reduction in death over the years, with women’s rates dropping more sharply.
#
#  Stroke
#
# **Overall Mortality Rate**
#
# * Stroke mortality rates reduced from 29.5 per 100,000 in 2011 to 20.1 per 100,000 in 2012. The rates fluctuated thereafter, reaching 21.9 per 100,000 in 2019.
#
# * The variability in stroke mortality rates suggests differing  impacts of stroke preventing measures and treatment over the years.
#
# **Gender Difference**
#
# *  Mortality rates for women were lower than those for men.
#
# * Mortality rates for stroke also decreased, but the rate of reduction was smaller in comparison to the reduction seen in heart disease.
#
# **Coronary Heart Disease CHD**
#
# **Overall Mortality Rate**
#
# * Mortality rates for coronary heart disease ranged from a high of 56.2 per 100,000 in 2010 to a low of 44.8 per 100,000 in 2019.
#
# * There was a general downward trend with some fluctuations, reflecting how improvements in treatment and prevention has reduced the deaths.
#
# **Gender Difference**
#
#
# * Mortality rates for women were lower than those for men.
#
# * The trend for women was similar to the overall pattern, with a reduction over the years.
#
# **Cardiovascular Disease CV**
#
# **Overall Mortality Rate**
#
# * CVD mortality rates were higher compared to other conditions, peaking at 181.2 per 100,000 in 2010 and falling to 158.6 per 100,000 in 2019.
#
# * Despite the reduction, CVD remained a significant cause of death with higher rates compared to other conditions.
#
# **Gender Difference**
#
# * Mortality rates for women were lower than those for men, but the gap was very less when compared to heart disease and stroke.
#
# **Heart Failure**
#
# **Overall Mortality Rate**
#
# * Heart failure rates showed considerable variations, with a peak of 44.3 per 100,000 in 2010 and a low of 23.5 per 100,000 in 2015.
#
# * The overall trend showed fluctuations without a clear upward or downward direction.
#
# **Gender Difference**
#
# Rates for women were consistently lower than those for men.
#
# The variability in rates for both genders suggests inconsistent impacts of treatment and management strategies.
#
# Conclusion According to the performed analysis, heart disease and cardiovascular disease had the highest mortality rates. It reflected how severe their impact on public health is. However, stroke and heart failure showed more variation but overall it reduced as the years passed therefore, indicating progress in treatment and prevention.
#
# **Analysis General Trends**
#
# * Heart Disease: A general decline in mortality rates was observed, with fluctuations indicating improvements in treatment and prevention strategies.
#
# * Stroke: Mortality rates showed variability but a general decline, reflecting varying effectiveness of public health initiatives.
#
# * Cardiovascular Heart Disease: A steady decrease in mortality rates suggests advances in medical care and prevention.
#
# * Cardiovascular Disease: Despite a decline, cardiovascular disease remained a leading cause of death, highlighting the need for continued focus.
#
# * Heart Failure: Variable trends suggest inconsistent progress, indicating areas for improvement in treatment strategies.

# %%
# Import the required libraries and dependencies
import pandas as pd
import datetime as dt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Define the path to the CSV file
data_path = "Resources/HealthData.csv"

# %%
# Load the data without specifying dtype for problematic columns
df = pd.read_csv(
    data_path,
    dtype={
        'LocationAbbr': 'str',
        'LocationDesc': 'str',
        'GeographicLevel': 'str',
        'DataSource': 'str',
        'Class': 'str',
        'Topic': 'str',
        'Data_Value': 'float64',  
        'Data_Value_Type': 'str',
        'Data_Value_Footnote_Symbol': 'str',
        'Data_Value_Footnote': 'str',
        'Confidence_limit_Low': 'float64',
        'Confidence_limit_High': 'float64',
        'StratificationCategory1': 'str',
        'Stratification1': 'str',
        'StratificationCategory2': 'str',
        'Stratification2': 'str',
        'StratificationCategory3': 'str',
        'Stratification3': 'str',
        'LocationID': 'int64'  # Assuming it's an integer
    },
    low_memory=False
)

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Year                                0
# LocationAbbr                        0
# LocationDesc                        0
# GeographicLevel                     0
# DataSource                          0
# Class                               0
# Topic                               0
# Data_Value                    2365475
# Data_Value_Unit                     0
# Data_Value_Type                     0
# Data_Value_Footnote_Symbol    3404765
# Data_Value_Footnote           3404765
# Confidence_limit_Low          2365475
# Confidence_limit_High         2365475
# StratificationCategory1             0
# Stratification1                     0
# StratificationCategory2             0
# Stratification2                     0
# StratificationCategory3             0
# Stratification3                     0
# LocationID                          0
# dtype: int64

# %%
# Columns with known missing data that are critical for analysis
critical_columns_with_missing_data = [
    'Data_Value',
    'Confidence_limit_Low',
    'Confidence_limit_High'
]

# Filter out rows with missing critical data
df_filtered = df.dropna(subset=critical_columns_with_missing_data)

# Display the filtered DataFrame to verify
df_filtered
# Out:
#                 Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 53              2016           AL      Autauga          County       NVSS
# 79              2011           AL      Autauga          County       NVSS
# 106             2017           AL      Autauga          County       NVSS
# 108             2017           AL      Autauga          County       NVSS
# 109             2016           AL      Autauga          County       NVSS
# ...              ...          ...          ...             ...        ...
# 5770235  1999 - 2010           WY       Weston          County       NVSS
# 5770236  2010 - 2019           WY       Weston          County       NVSS
# 5770237  1999 - 2010           WY       Weston          County       NVSS
# 5770238  1999 - 2010           WY       Weston          County       NVSS
# 5770239  2010 - 2019           WY       Weston          County       NVSS
#
#                            Class                         Topic  Data_Value  \
# 53       Cardiovascular Diseases                    All stroke        25.7
# 79       Cardiovascular Diseases                    All stroke        29.5
# 106      Cardiovascular Diseases                    All stroke        33.6
# 108      Cardiovascular Diseases             All heart disease       128.7
# 109      Cardiovascular Diseases             All heart disease       128.1
# ...                          ...                           ...         ...
# 5770235  Cardiovascular Diseases  Coronary heart disease (CHD)       -33.4
# 5770236  Cardiovascular Diseases  Cardiovascular disease (CVD)        -6.7
# 5770237  Cardiovascular Diseases  Cardiovascular disease (CVD)       -31.5
# 5770238  Cardiovascular Diseases                 Heart failure       -20.0
# 5770239  Cardiovascular Diseases                 Heart failure        -1.9
#
#         Data_Value_Unit                                   Data_Value_Type  \
# 53          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 79          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 106         per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 108         per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 109         per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# ...                 ...                                               ...
# 5770235               %                              Total percent change
# 5770236               %                              Total percent change
# 5770237               %                              Total percent change
# 5770238               %                              Total percent change
# 5770239               %                              Total percent change
#
#          ... Data_Value_Footnote Confidence_limit_Low  Confidence_limit_High  \
# 53       ...                 NaN                 21.3                   30.9
# 79       ...                 NaN                 22.9                   39.7
# 106      ...                 NaN                 25.4                   44.1
# 108      ...                 NaN                113.1                  144.7
# 109      ...                 NaN                114.1                  145.5
# ...      ...                 ...                  ...                    ...
# 5770235  ...                 NaN                -46.3                  -19.5
# 5770236  ...                 NaN                -20.4                    5.7
# 5770237  ...                 NaN                -41.0                  -20.4
# 5770238  ...                 NaN                -41.7                   -2.9
# 5770239  ...                 NaN                -23.0                   20.2
#
#          StratificationCategory1          Stratification1  \
# 53                     Age group         Ages 35-64 years
# 79                     Age group         Ages 35-64 years
# 106                    Age group         Ages 35-64 years
# 108                    Age group         Ages 35-64 years
# 109                    Age group         Ages 35-64 years
# ...                          ...                      ...
# 5770235                Age group  Ages 65 years and older
# 5770236                Age group  Ages 65 years and older
# 5770237                Age group  Ages 65 years and older
# 5770238                Age group  Ages 65 years and older
# 5770239                Age group  Ages 65 years and older
#
#         StratificationCategory2 Stratification2 StratificationCategory3  \
# 53                         Race         Overall                     Sex
# 79                         Race         Overall                     Sex
# 106                        Race         Overall                     Sex
# 108                        Race         Overall                     Sex
# 109                        Race         Overall                     Sex
# ...                         ...             ...                     ...
# 5770235                    Race           White                     Sex
# 5770236                    Race           White                     Sex
# 5770237                    Race           White                     Sex
# 5770238                    Race           White                     Sex
# 5770239                    Race           White                     Sex
#
#         Stratification3 LocationID
# 53              Overall       1001
# 79                  Men       1001
# 106                 Men       1001
# 108             Overall       1001
# 109             Overall       1001
# ...                 ...        ...
# 5770235         Overall      56045
# 5770236         Overall      56045
# 5770237         Overall      56045
# 5770238         Overall      56045
# 5770239         Overall      56045
#
# [3404765 rows x 21 columns]

# %%
print(df_filtered.isnull().sum())
# Out:
# Year                                0
# LocationAbbr                        0
# LocationDesc                        0
# GeographicLevel                     0
# DataSource                          0
# Class                               0
# Topic                               0
# Data_Value                          0
# Data_Value_Unit                     0
# Data_Value_Type                     0
# Data_Value_Footnote_Symbol    3404765
# Data_Value_Footnote           3404765
# Confidence_limit_Low                0
# Confidence_limit_High               0
# StratificationCategory1             0
# Stratification1                     0
# StratificationCategory2             0
# Stratification2                     0
# StratificationCategory3             0
# Stratification3                     0
# LocationID                          0
# dtype: int64

# %%
# Drop the columns with only missing values
columns_to_drop = ['Data_Value_Footnote_Symbol', 'Data_Value_Footnote']
df_cleaned = df_filtered.drop(columns=columns_to_drop)

# Drop the 'DataSource' column, not necessary for analysis 
df_cleaned = df_cleaned.drop(columns=['DataSource'])

# Display the cleaned DataFrame to verify
df_cleaned
# Out:
#                 Year LocationAbbr LocationDesc GeographicLevel  \
# 53              2016           AL      Autauga          County
# 79              2011           AL      Autauga          County
# 106             2017           AL      Autauga          County
# 108             2017           AL      Autauga          County
# 109             2016           AL      Autauga          County
# ...              ...          ...          ...             ...
# 5770235  1999 - 2010           WY       Weston          County
# 5770236  2010 - 2019           WY       Weston          County
# 5770237  1999 - 2010           WY       Weston          County
# 5770238  1999 - 2010           WY       Weston          County
# 5770239  2010 - 2019           WY       Weston          County
#
#                            Class                         Topic  Data_Value  \
# 53       Cardiovascular Diseases                    All stroke        25.7
# 79       Cardiovascular Diseases                    All stroke        29.5
# 106      Cardiovascular Diseases                    All stroke        33.6
# 108      Cardiovascular Diseases             All heart disease       128.7
# 109      Cardiovascular Diseases             All heart disease       128.1
# ...                          ...                           ...         ...
# 5770235  Cardiovascular Diseases  Coronary heart disease (CHD)       -33.4
# 5770236  Cardiovascular Diseases  Cardiovascular disease (CVD)        -6.7
# 5770237  Cardiovascular Diseases  Cardiovascular disease (CVD)       -31.5
# 5770238  Cardiovascular Diseases                 Heart failure       -20.0
# 5770239  Cardiovascular Diseases                 Heart failure        -1.9
#
#         Data_Value_Unit                                   Data_Value_Type  \
# 53          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 79          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 106         per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 108         per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# 109         per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate
# ...                 ...                                               ...
# 5770235               %                              Total percent change
# 5770236               %                              Total percent change
# 5770237               %                              Total percent change
# 5770238               %                              Total percent change
# 5770239               %                              Total percent change
#
#          Confidence_limit_Low  Confidence_limit_High StratificationCategory1  \
# 53                       21.3                   30.9               Age group
# 79                       22.9                   39.7               Age group
# 106                      25.4                   44.1               Age group
# 108                     113.1                  144.7               Age group
# 109                     114.1                  145.5               Age group
# ...                       ...                    ...                     ...
# 5770235                 -46.3                  -19.5               Age group
# 5770236                 -20.4                    5.7               Age group
# 5770237                 -41.0                  -20.4               Age group
# 5770238                 -41.7                   -2.9               Age group
# 5770239                 -23.0                   20.2               Age group
#
#                  Stratification1 StratificationCategory2 Stratification2  \
# 53              Ages 35-64 years                    Race         Overall
# 79              Ages 35-64 years                    Race         Overall
# 106             Ages 35-64 years                    Race         Overall
# 108             Ages 35-64 years                    Race         Overall
# 109             Ages 35-64 years                    Race         Overall
# ...                          ...                     ...             ...
# 5770235  Ages 65 years and older                    Race           White
# 5770236  Ages 65 years and older                    Race           White
# 5770237  Ages 65 years and older                    Race           White
# 5770238  Ages 65 years and older                    Race           White
# 5770239  Ages 65 years and older                    Race           White
#
#         StratificationCategory3 Stratification3  LocationID
# 53                          Sex         Overall        1001
# 79                          Sex             Men        1001
# 106                         Sex             Men        1001
# 108                         Sex         Overall        1001
# 109                         Sex         Overall        1001
# ...                         ...             ...         ...
# 5770235                     Sex         Overall       56045
# 5770236                     Sex         Overall       56045
# 5770237                     Sex         Overall       56045
# 5770238                     Sex         Overall       56045
# 5770239                     Sex         Overall       56045
#
# [3404765 rows x 18 columns]

# %%
# Convert the 'Year' column to numeric, handling errors
# Anaconda Assistant provided this error handling
df_cleaned.loc[:, 'Year'] = pd.to_numeric(df_cleaned['Year'], errors='coerce')

# Drop any rows where 'Year' could not be converted to a valid integer
df_cleaned = df_cleaned.dropna(subset=['Year'])

# Convert 'Year' column to integer type
df_cleaned.loc[:, 'Year'] = df_cleaned['Year'].astype(int)

# Filter the dataset to include only rows from the most recent years (2010-2019)
df_recent_years = df_cleaned[df_cleaned['Year'] >= 2010]

# Check the number of rows in the filtered dataset
print(f"The filtered DataFrame (2010-2019) has {len(df_recent_years)} rows.")
# Out:
# The filtered DataFrame (2010-2019) has 1480500 rows.

# %%
# Check all columns in the DataFrame for unique values
for column in df_recent_years.columns:
    unique_values = df_recent_years[column].unique()
    if len(unique_values) == 1:
        print(f"The '{column}' column has the same value across all rows.")
        print(f"The single value is: {unique_values[0]}")
# Out:
# The 'GeographicLevel' column has the same value across all rows.
# The single value is: County
# The 'Class' column has the same value across all rows.
# The single value is: Cardiovascular Diseases
# The 'Data_Value_Unit' column has the same value across all rows.
# The single value is: per 100,000
# The 'Data_Value_Type' column has the same value across all rows.
# The single value is: Age-Standardized, Spatiotemporally Smoothed Rate
# The 'StratificationCategory1' column has the same value across all rows.
# The single value is: Age group
# The 'StratificationCategory2' column has the same value across all rows.
# The single value is: Race
# The 'StratificationCategory3' column has the same value across all rows.
# The single value is: Sex

# %%
# List of columns that have the same value across all rows and should be dropped
columns_to_drop = [
    'GeographicLevel', 
    'Class', 
    'Data_Value_Unit', 
    'Data_Value_Type',
    'StratificationCategory1',
    'StratificationCategory2',
    'StratificationCategory3'
]

# Drop the specified columns
df_recent_years = df_recent_years.drop(columns=columns_to_drop)

# Verify the columns have been dropped
print("Remaining columns after dropping non-unique columns:")
print(df_recent_years.columns)
# Out:
# Remaining columns after dropping non-unique columns:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'Topic', 'Data_Value',
#        'Confidence_limit_Low', 'Confidence_limit_High', 'Stratification1',
#        'Stratification2', 'Stratification3', 'LocationID'],
#       dtype='object')

# %%
# Check for duplicates
duplicate_rows = df_recent_years.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")
# Out:
# Number of duplicate rows: 0

# %%
# Example: Identifying potential outliers in 'Data_Value'
df_recent_years['Data_Value'].describe()
# Out:
# count    1.480500e+06
# mean     4.218941e+02
# std      5.299608e+02
# min      0.000000e+00
# 25%      4.120000e+01
# 50%      1.809000e+02
# 75%      5.836000e+02
# max      3.993400e+03
# Name: Data_Value, dtype: float64

# %%
# Filtering out extreme outliers
lower_bound = df_recent_years['Data_Value'].quantile(0.01)
upper_bound = df_recent_years['Data_Value'].quantile(0.99)

df_recent_years = df_recent_years[(df_recent_years['Data_Value'] >= lower_bound) & 
                                  (df_recent_years['Data_Value'] <= upper_bound)]
print(f"After outlier removal, the DataFrame has {len(df_recent_years)} rows.")
# Out:
# After outlier removal, the DataFrame has 1451146 rows.

# %%
# Identify the data types
print(df_recent_years.dtypes)
# Out:
# Year                      object
# LocationAbbr              object
# LocationDesc              object
# Topic                     object
# Data_Value               float64
# Confidence_limit_Low     float64
# Confidence_limit_High    float64
# Stratification1           object
# Stratification2           object
# Stratification3           object
# LocationID                 int64
# dtype: object

# %%
# Rename the columns
df_recent_years = df_recent_years.rename(columns={
    'LocationAbbr': 'State',
    'LocationDesc': 'County',
    'Topic': 'CauseOfDeath',
    'Data_Value': 'MortalityRate',  # Assuming this represents the rate per 100,000
    'Confidence_limit_Low': 'ConfLow',
    'Confidence_limit_High': 'ConfHigh',
    'Stratification1': 'AgeGroup',
    'Stratification2': 'Race',
    'Stratification3': 'Sex'
})

# Verify the column renaming
print("Columns after renaming:")
print(df_recent_years.columns)
# Out:
# Columns after renaming:
# Index(['Year', 'State', 'County', 'CauseOfDeath', 'MortalityRate', 'ConfLow',
#        'ConfHigh', 'AgeGroup', 'Race', 'Sex', 'LocationID'],
#       dtype='object')

# %%
df_recent_years
# Out:
#          Year State   County       CauseOfDeath  MortalityRate  ConfLow  \
# 53       2016    AL  Autauga         All stroke           25.7     21.3
# 79       2011    AL  Autauga         All stroke           29.5     22.9
# 106      2017    AL  Autauga         All stroke           33.6     25.4
# 108      2017    AL  Autauga  All heart disease          128.7    113.1
# 109      2016    AL  Autauga  All heart disease          128.1    114.1
# ...       ...   ...      ...                ...            ...      ...
# 5268484  2018    WY   Weston      Heart failure          458.8    393.4
# 5268487  2014    WY   Weston      Heart failure          470.0    404.0
# 5268490  2011    WY   Weston      Heart failure          467.7    395.0
# 5268495  2013    WY   Weston      Heart failure          474.9    403.2
# 5268498  2019    WY   Weston      Heart failure          478.2    408.0
#
#          ConfHigh                 AgeGroup     Race      Sex  LocationID
# 53           30.9         Ages 35-64 years  Overall  Overall        1001
# 79           39.7         Ages 35-64 years  Overall      Men        1001
# 106          44.1         Ages 35-64 years  Overall      Men        1001
# 108         144.7         Ages 35-64 years  Overall  Overall        1001
# 109         145.5         Ages 35-64 years  Overall  Overall        1001
# ...           ...                      ...      ...      ...         ...
# 5268484     554.6  Ages 65 years and older    White  Overall       56045
# 5268487     543.2  Ages 65 years and older    White  Overall       56045
# 5268490     539.8  Ages 65 years and older    White  Overall       56045
# 5268495     551.1  Ages 65 years and older    White  Overall       56045
# 5268498     564.6  Ages 65 years and older    White  Overall       56045
#
# [1451146 rows x 11 columns]

# %%
# Save the cleaned DataFrame to a new CSV file
df_recent_years.to_csv('Resources/Cleaned_HealthData.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# import data
path = 'Resources/Cleaned_HealthData.csv'
heart = pd.read_csv(path)

# check first five rows:
display(heart.head())
display(heart.tail())
# Out:
#    Year State   County       CauseOfDeath  MortalityRate  ConfLow  ConfHigh  \
# 0  2016    AL  Autauga         All stroke           25.7     21.3      30.9
# 1  2011    AL  Autauga         All stroke           29.5     22.9      39.7
# 2  2017    AL  Autauga         All stroke           33.6     25.4      44.1
# 3  2017    AL  Autauga  All heart disease          128.7    113.1     144.7
# 4  2016    AL  Autauga  All heart disease          128.1    114.1     145.5
#
#            AgeGroup     Race      Sex  LocationID
# 0  Ages 35-64 years  Overall  Overall        1001
# 1  Ages 35-64 years  Overall      Men        1001
# 2  Ages 35-64 years  Overall      Men        1001
# 3  Ages 35-64 years  Overall  Overall        1001
# 4  Ages 35-64 years  Overall  Overall        1001
#          Year State  County   CauseOfDeath  MortalityRate  ConfLow  ConfHigh  \
# 1451141  2018    WY  Weston  Heart failure          458.8    393.4     554.6
# 1451142  2014    WY  Weston  Heart failure          470.0    404.0     543.2
# 1451143  2011    WY  Weston  Heart failure          467.7    395.0     539.8
# 1451144  2013    WY  Weston  Heart failure          474.9    403.2     551.1
# 1451145  2019    WY  Weston  Heart failure          478.2    408.0     564.6
#
#                         AgeGroup   Race      Sex  LocationID
# 1451141  Ages 65 years and older  White  Overall       56045
# 1451142  Ages 65 years and older  White  Overall       56045
# 1451143  Ages 65 years and older  White  Overall       56045
# 1451144  Ages 65 years and older  White  Overall       56045
# 1451145  Ages 65 years and older  White  Overall       56045

# %%
# The count of unique values in the heart DataFrame.
heart.nunique()
# Out:
# Year                10
# State               51
# County            1800
# CauseOfDeath         5
# MortalityRate    20275
# ConfLow          18929
# ConfHigh         23353
# AgeGroup             2
# Race                 6
# Sex                  3
# LocationID        3083
# dtype: int64

# %%
print(heart.columns)
# Out:
# Index(['Year', 'State', 'County', 'CauseOfDeath', 'MortalityRate', 'ConfLow',
#        'ConfHigh', 'AgeGroup', 'Race', 'Sex', 'LocationID'],
#       dtype='object')

# %%
# Define your custom color palette
custom_palette = {
    'Men': '#FF0000',    # Light red color
    'Women': '#2ca02c', # Green color 
    'Overall': '#ff7f0e',  # Orange color
}

# Plot the data with the custom color palette
plt.figure(figsize=(14, 7))
sns.boxplot(data=heart, x='AgeGroup', y='MortalityRate', hue='Sex', palette=custom_palette)
plt.title('Mortality Rates by Age Group and Sex')
plt.xlabel('Age Group')
plt.ylabel('Number of Death per 100,000')
plt.legend(title='Sex')
plt.savefig('Output_plot/Mortality Rates by Age Group and Sex.jpg', format='jpg')
plt.show()

# %%
# Set 'Year' and 'AgeGroup' as the index
heart.set_index(['Year', 'AgeGroup'], inplace=True)

# Plot the data

plt.figure(figsize=(14, 8))
sns.lineplot(data=heart, x='Year', y='MortalityRate', hue='CauseOfDeath', style='AgeGroup', markers=True, dashes=False)
plt.title('Mortality Rate Trends by Cause of Death and Age Group in the USA')
plt.xlabel('Year')
plt.ylabel('Mortality Rate (per 100,000)')
plt.grid(True)
plt.legend(title='Cause of Death and Age Group')
plt.savefig('Output_plot/Mortality Rate Trends by Cause of Death and Age Group in the USA.jpg', format='jpg')
plt.show()
# Out:
# C:\Users\ifons\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ifons\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Summary statistics
display(heart.groupby('CauseOfDeath')['MortalityRate'].describe())
# Out:
#                                  count        mean         std   min    25%  \
# CauseOfDeath
# All heart disease             294965.0  598.759540  568.487443  12.1   95.8
# All stroke                    295852.0  137.999317  136.446420   5.5   14.4
# Cardiovascular disease (CVD)  282439.0  731.206174  704.038025  12.6  115.6
# Coronary heart disease (CHD)  296088.0  348.203714  346.637439   5.5   58.2
# Heart failure                 281802.0  228.861036  236.239699   5.5   14.1
#
#                                 50%     75%     max
# CauseOfDeath
# All heart disease             211.2  1129.1  2033.0
# All stroke                     33.3   267.4   983.6
# Cardiovascular disease (CVD)  236.0  1465.3  2033.0
# Coronary heart disease (CHD)  134.6   619.0  2028.9
# Heart failure                  47.5   444.7  1744.9

# %%
#@title Your Title Here Trends Over Time
plt.figure(figsize=(14, 7))
sns.lineplot(data=heart, x='Year', y='MortalityRate', hue='CauseOfDeath')
plt.title('Trends in Mortality Rates Over Time')
plt.xlabel('Year')
plt.ylabel('Average of Deaths per 100,000')
plt.savefig('Output_plot/Trends in Mortality Rates Over Time.jpg', format='jpg')
plt.show()
# Out:
# C:\Users\ifons\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ifons\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#@title Boxplot by Cause of Death
plt.figure(figsize=(14, 7))
sns.boxplot(data=heart, x='CauseOfDeath', y='MortalityRate')
plt.title('Mortality Rate Distribution by Cause of Death')
plt.xticks(rotation=20)
plt.savefig('Output_plot/Mortality Rate Distribution by Cause of Death.jpg', format='jpg')
plt.show()

# %%
#@title Mortality Rates by Sex and Cause of Death
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.boxplot(data=heart, x='Sex', y='MortalityRate', hue='CauseOfDeath')
plt.title('Mortality Rates by Sex and Cause of Death')
plt.savefig('Output_plot/Mortality Rates by Sex and Cause of Death.jpg', format='jpg')
plt.show()

# %%
# Print a List of columns 
print(heart.columns)
# Out:
# Index(['State', 'County', 'CauseOfDeath', 'MortalityRate', 'ConfLow',
#        'ConfHigh', 'Race', 'Sex', 'LocationID'],
#       dtype='object')

# %%
#@title Race Based Average Mortality Rates by Cause of Death

# Define a dictionary for the custom color palette
custom_palette = {
    'All heart disease': '#FFA500',  # Orange color
    'All stroke': '#4682B4',         # Light blue color
    'Cardiovascular disease (CVD)': '#FF0000',  # Light red color
    'Coronary heart disease (CHD)': '#008000',  # Light green color
    'Heart failure': '#800080'       # Light purple color
}

# Define the list order of the categories
hue_order = ['All stroke', 'All heart disease', 'Coronary heart disease (CHD)', 'Cardiovascular disease (CVD)', 'Heart failure']

# Calculate yearly average mortality rates by cause of death
yearly_avg = heart.groupby(['Year', 'CauseOfDeath'])['MortalityRate'].mean().reset_index()

# Plot the data with the custom color palette and specified order
plt.figure(figsize=(14, 7))
sns.barplot(data=yearly_avg, x='Year', y='MortalityRate', hue='CauseOfDeath', palette=custom_palette, hue_order=hue_order)
plt.title('Yearly Average Mortality Rates by Cause of Death')
plt.xlabel('Year')
plt.ylabel('Number of Deaths per 100,000')
plt.legend(title='Cause of Death')
plt.savefig('Output_plot/Number of Deaths per 100,000', format='jpg')
plt.show()

# %%
#@title Race Based Average Mortality Rates by Cause of Death
yearly_avg = heart.groupby(['Race', 'CauseOfDeath'])['MortalityRate'].mean().reset_index()

# Define a dictionary for the custom color palette
custom_palette = {
    'All heart disease': '#FFA500',  # Orange color
    'All stroke': '#4682B4',         # Light blue color
    'Cardiovascular disease (CVD)': '#FF0000',  # Light red color
    'Coronary heart disease (CHD)': '#008000',  # Light green color
    'Heart failure': '#800080'       # Light purple color
}

# Define the list order of the categories
hue_order = ['All stroke', 'All heart disease', 'Coronary heart disease (CHD)', 'Cardiovascular disease (CVD)', 'Heart failure']

# Plotting 
plt.figure(figsize=(14, 7))
sns.barplot(data=yearly_avg, x='Race', y='MortalityRate', hue='CauseOfDeath', palette=custom_palette, hue_order=hue_order)
plt.title('Race Average Mortality Rates by Cause of Death')
plt.xlabel('Race')
plt.ylabel('Average of Deaths per 100,000')
plt.savefig('Output_plot/Race Average Mortality Rates by Cause of Death', format='jpg')
plt.show()

# %%
#@title Seperate Cateogrical Features & Numerical Features
import numpy as np
cat_cols=heart.select_dtypes(include=['object']).columns
num_cols = heart.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['State', 'County', 'CauseOfDeath', 'Race', 'Sex'], dtype='object')
# Numerical Variables:
# ['MortalityRate', 'ConfLow', 'ConfHigh', 'LocationID']

# %%
#@title Display skewness of each numerical attribute
for col in num_cols:
    print(col)
    print('Skew :', round(heart[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    heart[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=heart[col])
    plt.show()
# Out:
# MortalityRate
# Skew : 1.44
# ConfLow
# Skew : 1.5
# ConfHigh
# Skew : 1.38
# LocationID
# Skew : -0.08

# %%
# Calculate the average mortality rate by state
avg_mortality_rate = heart.groupby('State')['MortalityRate'].mean().sort_values(ascending=False)

# Create a color map
cmap = plt.get_cmap('rainbow')
colors = cmap(np.linspace(0, 1, len(avg_mortality_rate)))

# Define unique colors for MI and TX
state_colors = {state: color for state, color in zip(avg_mortality_rate.index, colors)}
state_colors['MI'] = 'red'  # Assign red color to Michigan
state_colors['TX'] = 'lightgreen'  # Assign blue color to Texas

# Apply the colors to the bar plot
bar_colors = [state_colors[state] for state in avg_mortality_rate.index]

# Plot the data
plt.figure(figsize=(10, 6))
avg_mortality_rate.plot.bar(color=bar_colors, fontsize=8)
plt.title("State Vs Average Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.savefig('Output_plot/State_Vs_Average_Mortality_Rate_2010_2019.jpg', format='jpg')
plt.show()

# %%
# Plot 2: Average MortalityRate by CauseOfDeath
plt.figure(figsize=(10,6))
heart.groupby('CauseOfDeath')['MortalityRate'].mean().sort_values(ascending=False).plot.bar(fontsize=12).set_title("CauseOfDeath Vs Average Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 3: Average MortalityRate by AgeGroup
plt.figure(figsize=(10,6))
heart.groupby('AgeGroup')['MortalityRate'].mean().sort_values(ascending=False).plot.bar(fontsize=12).set_title("Average AgeGroup Vs Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 4: Average MortalityRate by Race
plt.figure(figsize=(10,6))
heart.groupby('Race')['MortalityRate'].mean().sort_values(ascending=False).plot.bar(fontsize=12).set_title("Average Race Vs Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 5: Average MortalityRate by Sex
plt.figure(figsize=(10,6))
heart.groupby('Sex')['MortalityRate'].mean().sort_values(ascending=False).plot.bar(fontsize=12).set_title("Average Sex Vs Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 6: Average MortalityRate by Year (if Year is considered categorical for this analysis)
plt.figure(figsize=(10,6))
heart.groupby('Year')['MortalityRate'].mean().sort_values(ascending=False).plot.bar(fontsize=12).set_title("Average Year Vs Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 1: Average MortalityRate by State (Top 5 States)
plt.figure(figsize=(10,6))
top_states = heart.groupby('State')['MortalityRate'].mean().sort_values(ascending=False).head(5)
top_states.plot.bar(fontsize=12, color='skyblue').set_title("Top 5 States Vs Average Mortality Rate (2010-2019) ", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 2: Average MortalityRate by State (Bottom 5 States)
plt.figure(figsize=(10,6))
top_states = heart.groupby('State')['MortalityRate'].mean().sort_values(ascending=False).tail(5)
top_states.plot.bar(fontsize=12, color='red').set_title("Bottom 5 States Vs Average Mortality Rate (2010-2019) ", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 3: Average MortalityRate by County (Top 5 Counties)
plt.figure(figsize=(10,6))
top_county = heart.groupby('County')['MortalityRate'].mean().sort_values(ascending=False).head(5)
top_county.plot.bar(fontsize=12, color='skyblue').set_title("Top 5 Counties Vs Average Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 4: Average MortalityRate by County (Bottom 5 Counties)
plt.figure(figsize=(10,6))
top_states = heart.groupby('County')['MortalityRate'].mean().sort_values(ascending=False).tail(5)
top_states.plot.bar(fontsize=12, color='red').set_title("Bottom 5 Counties Vs Average Mortality Rate (2010-2019) ", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 5: Average MortalityRate by Sex
plt.figure(figsize=(10,6))
heart.groupby('Sex')['MortalityRate'].mean().sort_values(ascending=False).plot.bar(fontsize=12).set_title("Average Sex Vs Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 6: Average MortalityRate by Year (if Year is considered categorical for this analysis)
plt.figure(figsize=(10,6))
heart.groupby('Year')['MortalityRate'].mean().sort_values(ascending=False).plot.bar(fontsize=12).set_title("Average Year Vs Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 1: Average MortalityRate by State (Top 5 States)
plt.figure(figsize=(10,6))
top_states = heart.groupby('State')['MortalityRate'].mean().sort_values(ascending=False).head(5)
top_states.plot.bar(fontsize=12, color='skyblue').set_title("Top 5 States Vs Average Mortality Rate (2010-2019) ", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 2: Average MortalityRate by State (Bottom 5 States)
plt.figure(figsize=(10,6))
top_states = heart.groupby('State')['MortalityRate'].mean().sort_values(ascending=False).tail(5)
top_states.plot.bar(fontsize=12, color='red').set_title("Bottom 5 States Vs Average Mortality Rate (2010-2019) ", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 3: Average MortalityRate by County (Top 5 Counties)
plt.figure(figsize=(10,6))
top_county = heart.groupby('County')['MortalityRate'].mean().sort_values(ascending=False).head(5)
top_county.plot.bar(fontsize=12, color='skyblue').set_title("Top 5 Counties Vs Average Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 4: Average MortalityRate by County (Bottom 5 Counties)
plt.figure(figsize=(10,6))
top_states = heart.groupby('County')['MortalityRate'].mean().sort_values(ascending=False).tail(5)
top_states.plot.bar(fontsize=12, color='red').set_title("Bottom 5 Counties Vs Average Mortality Rate (2010-2019) ", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 5: Average MortalityRate by LocationID (Top 5 LocationID)
plt.figure(figsize=(10,6))
top_county = heart.groupby('LocationID')['MortalityRate'].mean().sort_values(ascending=False).head(5)
top_county.plot.bar(fontsize=12, color='skyblue').set_title("Top 5 LocationID Vs Average Mortality Rate  (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()

# %%
# Plot 6: Average MortalityRate by LocationID (Top 5 LocationID)
plt.figure(figsize=(10,6))
top_county = heart.groupby('LocationID')['MortalityRate'].mean().sort_values(ascending=False).tail(5)
top_county.plot.bar(fontsize=12, color='red').set_title("Bottom 5 Location ID Vs Average Mortality Rate (2010-2019)", fontsize=18)
plt.ylabel('Number of Deaths per 100,000')
plt.show()
